# %%
# akbar-december-2024-backup/DISCOGRAPHY/FADL_SHAKER/Fadl Shaker.Full Discography.BY.RoMaNTiCPoET/15.The Best Of (Al Rawae3).2010

# %%
# !gcloud auth login
# Out:
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=spdosqLTmJy4dkYCgHoWR0bntDK07e&prompt=consent&token_usage=remote&access_type=offline&code_challenge=7MIpwQhYHzz2K7-iubHS7k5jhCweNR4II6akENJ89EA&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0AeoWuM-jP_FbEi7WNIAgfcHDrS1gFA7wQCLAh6Juol6XEAtnyuon4uTc3a8LQ2fxpdHhRg
#
# You are now logged in as [ghurbal.akbar@gmail.com].
# ...

# %%
# !git clone https://github.com/akbargherbal/drums_segmenter.git
# Out:
# Cloning into 'drums_segmenter'...
# remote: Enumerating objects: 50, done.
# remote: Counting objects: 100% (50/50), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 50 (delta 10), reused 50 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (50/50), 56.17 KiB | 2.01 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
# !python ./drums_segmenter/src/main.py -h
# Out:
# Usage: main.py [OPTIONS]
#
#   Automated Drum Stem Extraction Based on Vocal Activity.
#
#   Separates each audio file into stems, detects vocal windows, then exports
#   only the drum segments that fall inside those windows. Instrumental breaks
#   are automatically excluded.
#
# Options:
#   --input DIRECTORY              Folder containing source audio files.
#                                  [required]
#   --output DIRECTORY             Folder for exported drum MP3s (created if
#                                  missing).  [required]
#   --stems-cache DIRECTORY        Directory where Demucs caches separated stems
#                                  between runs.  [default: ./stems_cache]
#   --vad-silence-duration FLOAT   Seconds of continuous silence required to
#                                  close a vocal window.  [default: 6.0]
#   --vad-threshold FLOAT          Silero VAD speech-probability threshold.
# ...

# %%
# !pip install librosa soundfile pydub audioread -q

# %%
# 1. Delete any local files/folders that might be shadowing the real Demucs package
# !rm -rf ./drums_segmenter/src/demucs
# !rm -f ./drums_segmenter/src/demucs.py

# 2. Ensure pip and python are perfectly synced by using the same executable
# !python3 -m pip install -q -U "demucs>=4.0.0"

# 3. Run the script using python3 to guarantee it uses the environment we just verified
# !python3 ./drums_segmenter/src/main.py --input ./FADL_SHAKER_01/ --output ./FADL_SHAKER_01_DRUMS
# Out:
# 🖥️  Device: CUDA  (Tesla T4)
# 🔊  Loading Silero VAD model...
# 🔊  Silero VAD ready.
#
# 📂  Found 16 audio file(s) in: FADL_SHAKER_01
# ...
#
# [1/16] 01.Rouh.mp3
#     🎵  Separating stems...
#     ❌  Error processing 01.Rouh.mp3: No module named 'demucs.api'
#
# [2/16] 02.Ya Mesaharny El Lail.mp3
#     🎵  Separating stems...
#     ❌  Error processing 02.Ya Mesaharny El Lail.mp3: No module named 'demucs.api'
#
# [3/16] 03.Allah We'allam.mp3
#     🎵  Separating stems...
#     ❌  Error processing 03.Allah We'allam.mp3: No module named 'demucs.api'
#
# [4/16] 04.Ya Hyat Al Roh.mp3
#     🎵  Separating stems...
#     ❌  Error processing 04.Ya Hyat Al Roh.mp3: No module named 'demucs.api'
#
# [5/16] 05.Akhedny Ma'ak.mp3
#     🎵  Separating stems...
#     ❌  Error processing 05.Akhedny Ma'ak.mp3: No module named 'demucs.api'
#
# [6/16] 06.Fakerny Nseetak.mp3
#     🎵  Separating stems...
#     ❌  Error processing 06.Fakerny Nseetak.mp3: No module named 'demucs.api'
#
# [7/16] 07.M'assar Feya.mp3
# ...

# %%
# !python ./drums_segmenter/src/main.py --input ./FADL_SHAKER_01/ --output ./FADL_SHAKER_01_DRUMS
# Out:
# 🖥️  Device: CUDA  (Tesla T4)
# 🔊  Loading Silero VAD model...
# 🔊  Silero VAD ready.
#
# 📂  Found 16 audio file(s) in: FADL_SHAKER_01
# ...
#
# [1/16] 01.Rouh.mp3
#     🎵  Separating stems...
# Downloading: "https://dl.fbaipublicfiles.com/demucs/hybrid_transformer/955717e8-8726e21a.th" to /root/.cache/torch/hub/checkpoints/955717e8-8726e21a.th
# 100% 80.2M/80.2M [00:00<00:00, 194MB/s]
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /tmp/tmpjrpky5lj/htdemucs
# Separating track FADL_SHAKER_01/01.Rouh.mp3
# 100%|██████████████████████████████████████████████| 327.59999999999997/327.59999999999997 [00:13<00:00, 23.42seconds/s]
# /usr/local/lib/python3.12/dist-packages/torchaudio/__init__.py:178: UserWarning: The 'encoding' parameter is not fully supported by TorchCodec AudioEncoder.
#   return save_with_torchcodec(
# ...

# %%
# !PYTHONPATH=./drums_segmenter/src python3 -c "import demucs; print('\n🚨 DEMUCS IS BEING LOADED FROM:', demucs.__file__, '\n')"
# Out:
# 🚨 DEMUCS IS BEING LOADED FROM: /usr/local/lib/python3.12/dist-packages/demucs/__init__.py

# %%
# !gsutil -m cp -r ./FADL_SHAKER_01_DRUMS/ gs://akbar-december-2024-backup/DISCOGRAPHY/
# Out:
# Google recommends using Gcloud storage CLI (https://docs.cloud.google.com/storage/docs/discover-object-storage-gcloud) instead of gsutil. Please refer to migration guide (https://docs.cloud.google.com/storage/docs/gsutil-transition-to-gcloud) for assistance.
# Copying file://./FADL_SHAKER_01_DRUMS/09.Law Ala Albi_drums_01.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/13.Ya Ghayib_drums_01.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/12.Dehket El Donya_drums_03.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/06.Fakerny Nseetak_drums_02.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/04.Ya Hyat Al Roh_drums_01.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/16.Baya' El Oulob_drums_01.mp3 [Content-Type=audio/mpeg]...
# Copying file://./FADL_SHAKER_01_DRUMS/10.El'am El Gedeed_drums_02.mp3 [Content-Type=audio/mpeg]...
# ...
